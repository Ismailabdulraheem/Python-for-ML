# %% [markdown]
# Import necessary libraries and modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from plt_logistic_loss import plt_logistic_cost, plt_simple_example, soup_bowl, plt_logistic_squared_error

# %% [markdown]
# Create dataset

# %%
x_train = np.array([0., 1, 2, 3, 4, 5], dtype = np.longdouble)
y_train = np.array([0., 0, 0, 1, 1, 1], dtype = np.longdouble)
plt_simple_example(x_train, y_train)

# %%
soup_bowl()

# %% [markdown]
# If a squared error cost is used for logistic regression, it does not produce a convex loss function.

# %%
plt_logistic_squared_error(x_train , y_train)
plt.show()

# %% [markdown]
# ### Logistic loss function

# %% [markdown]
# \begin{equation}
#   loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) = \begin{cases}
#     - \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) & \text{if $y^{(i)}=1$}\\
#     - \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) & \text{if $y^{(i)}=0$}
#   \end{cases}
# \end{equation}

# %%
plt_logistic_cost(x_train,y_train)
# Out:
# array([[12.11593817, 11.38142824, 10.64700033, ...,  5.74817973,
#          5.93185254,  6.11552555],
#        [12.3348674 , 11.60028381, 10.86574947, ...,  5.53992579,
#          5.72359816,  5.90727087],
#        [12.56404064, 11.82941284, 11.0948146 , ...,  5.34185036,
#          5.525522  ,  5.7091942 ],
#        ...,
#        [21.48717949, 20.75248561, 20.01779173, ...,  0.59747467,
#          0.71753235,  0.83885368],
#        [21.74358974, 21.00889587, 20.27420199, ...,  0.51504527,
#          0.63352046,  0.75404807],
#        [22.        , 21.26530612, 20.53061225, ...,  0.43456238,
#          0.55050217,  0.66974757]], dtype=float64)
